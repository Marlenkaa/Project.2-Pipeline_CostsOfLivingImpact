# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
costs = pd.read_csv('INPUT/cost_of_life_by_country.csv')
happiness = pd.read_csv('INPUT/2019.csv')

# %%
costs.head()
# Out:
#    Unnamed: 0  Rank     Country  Meal, Inexpensive Restaurant  \
# 0           0   NaN  Kazakhstan                          4.75
# 1           1   NaN    Paraguay                          3.45
# 2           2   NaN    Portugal                          7.50
# 3           3   NaN       Syria                          3.61
# 4           4   NaN      Greece                         10.00
#
#    Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              23.75
# 1                                              20.72
# 2                                              30.00
# 3                                              14.00
# 4                                              31.00
#
#    McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                            4.28
# 1                                            3.52
# 2                                            6.00
# 3                                            3.61
# ...

# %%
costs.columns
# Out:
# Index(['Unnamed: 0', 'Rank', 'Country', 'Meal, Inexpensive Restaurant',
#        'Meal for 2 People, Mid-range Restaurant, Three-course',
#        'McMeal at McDonalds (or Equivalent Combo Meal)',
#        'Domestic Beer (0.5 liter draught)',
#        'Imported Beer (0.33 liter bottle)', 'Coke/Pepsi (0.33 liter bottle)',
#        'Water (0.33 liter bottle) ', 'Milk (regular), (1 liter)',
#        'Loaf of Fresh White Bread (500g)', 'Eggs (regular) (12)',
#        'Local Cheese (1kg)', 'Water (1.5 liter bottle)',
#        'Bottle of Wine (Mid-Range)', 'Domestic Beer (0.5 liter bottle)',
#        'Cigarettes 20 Pack (Marlboro)', 'One-way Ticket (Local Transport)',
#        'Chicken Breasts (Boneless, Skinless), (1kg)',
#        'Monthly Pass (Regular Price)', 'Gasoline (1 liter)',
#        'Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car)',
#        'Apartment (1 bedroom) in City Centre',
#        'Apartment (1 bedroom) Outside of Centre',
# ...

# %%
costs.rename(columns={'Meal, Inexpensive Restaurant':'restaurant',
                      'Meal for 2 People, Mid-range Restaurant, Three-course':'mid-range restaurant',
                      'McMeal at McDonalds (or Equivalent Combo Meal)':'mcdonalds',
                      'Bottle of Wine (Mid-Range)':'wine',
                      'Cigarettes 20 Pack (Marlboro)':'cigarettes',
                      'Monthly Pass (Regular Price)':'public transport',
                      'Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car)':'car',
                      'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)':'internet',
                      'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment':'utilities',
                      'Fitness Club, Monthly Fee for 1 Adult':'fitness',
                      'Cinema, International Release, 1 Seat':'cinema',
                      'Apartment (1 bedroom) in City Centre':'rent',
                      'Average Monthly Net Salary (After Tax)':'salary',
                      'Country':'country'
                     }, 
                 inplace=True)

# %%
costs['supermarket'] = costs['Milk (regular), (1 liter)'] + costs['Loaf of Fresh White Bread (500g)'] + costs['Rice (white), (1kg)'] + costs['Eggs (regular) (12)'] + costs['Local Cheese (1kg)'] + costs['Chicken Breasts (Boneless, Skinless), (1kg)'] + costs['Beef Round (1kg) (or Equivalent Back Leg Red Meat)'] + costs['Apples (1kg)'] + costs['Banana (1kg)'] + costs['Oranges (1kg)'] + costs['Tomato (1kg)'] + costs['Potato (1kg)'] + costs['Onion (1kg)'] + costs['Lettuce (1 head)']

# %%
costs.head()
# Out:
#    Unnamed: 0  Rank     country  restaurant  mid-range restaurant  mcdonalds  \
# 0           0   NaN  Kazakhstan        4.75                 23.75       4.28
# 1           1   NaN    Paraguay        3.45                 20.72       3.52
# 2           2   NaN    Portugal        7.50                 30.00       6.00
# 3           3   NaN       Syria        3.61                 14.00       3.61
# 4           4   NaN      Greece       10.00                 31.00       6.00
#
#    Domestic Beer (0.5 liter draught)  Imported Beer (0.33 liter bottle)  \
# 0                               1.19                               1.16
# 1                               0.83                               1.10
# 2                               1.80                               1.86
# 3                               1.35                               1.42
# 4                               4.00                               1.79
#
#    Coke/Pepsi (0.33 liter bottle)  Water (0.33 liter bottle)   \
# ...

# %%
df1 = costs[['country', 'supermarket', 'restaurant', 'mid-range restaurant', 'mcdonalds', 'wine', 'cigarettes', 'rent', 'utilities', 'internet', 'fitness', 'cinema', 'public transport', 'car', 'salary']]

# %%
df1.head()
# Out:
#       country  supermarket  restaurant  mid-range restaurant  mcdonalds  wine  \
# 0  Kazakhstan        22.51        4.75                 23.75       4.28  4.75
# 1    Paraguay        21.52        3.45                 20.72       3.52  5.53
# 2    Portugal        33.51        7.50                 30.00       6.00  4.00
# 3       Syria        20.82        3.61                 14.00       3.61  2.94
# 4      Greece        37.29       10.00                 31.00       6.00  6.25
#
#    cigarettes    rent  utilities  internet  fitness  cinema  public transport  \
# 0        0.95  266.08      49.38     10.40    37.80    3.56             16.63
# 1        1.38  220.26      44.63     25.79    22.27    4.83             21.02
# 2        5.00  619.65      96.61     31.86    32.75    7.00             35.00
# 3        2.34  176.54      17.15     30.94    13.07    4.38              9.68
# 4        4.50  323.04     145.67     30.81    32.34    8.00             30.00
#
#         car  salary
# ...

# %%
happiness.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
happiness.rename(columns={'Country or region':'country',
                      'Score':'happiness',
                     }, 
                 inplace=True)

# %%
happiness.head()
# Out:
#    Overall rank      country  happiness  GDP per capita  Social support  \
# 0             1      Finland      7.769           1.340           1.587
# 1             2      Denmark      7.600           1.383           1.573
# 2             3       Norway      7.554           1.488           1.582
# 3             4      Iceland      7.494           1.380           1.624
# 4             5  Netherlands      7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
merged = pd.merge(df1, happiness, how='inner', on=['country'])

# %%
merged.head()
# Out:
#       country  supermarket  restaurant  mid-range restaurant  mcdonalds  wine  \
# 0  Kazakhstan        22.51        4.75                 23.75       4.28  4.75
# 1    Paraguay        21.52        3.45                 20.72       3.52  5.53
# 2    Portugal        33.51        7.50                 30.00       6.00  4.00
# 3       Syria        20.82        3.61                 14.00       3.61  2.94
# 4      Greece        37.29       10.00                 31.00       6.00  6.25
#
#    cigarettes    rent  utilities  internet  fitness  cinema  public transport  \
# 0        0.95  266.08      49.38     10.40    37.80    3.56             16.63
# 1        1.38  220.26      44.63     25.79    22.27    4.83             21.02
# 2        5.00  619.65      96.61     31.86    32.75    7.00             35.00
# 3        2.34  176.54      17.15     30.94    13.07    4.38              9.68
# 4        4.50  323.04     145.67     30.81    32.34    8.00             30.00
#
# ...

# %%
a=happiness[(happiness['country']=='Paraguay')]
a
# Out:
#     Overall rank   country  happiness  GDP per capita  Social support  \
# 62            63  Paraguay      5.743           0.855           1.475
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 62                    0.777                         0.514       0.184
#
#     Perceptions of corruption
# 62                       0.08

# %%
merged.count()
# Out:
# country                         97
# supermarket                     97
# restaurant                      97
# mid-range restaurant            97
# mcdonalds                       97
# wine                            97
# cigarettes                      97
# rent                            97
# utilities                       97
# internet                        97
# fitness                         97
# cinema                          97
# public transport                97
# car                             97
# salary                          97
# Overall rank                    97
# happiness                       97
# GDP per capita                  97
# Social support                  97
# Healthy life expectancy         97
# Freedom to make life choices    97
# Generosity                      97
# Perceptions of corruption       97
# dtype: int64

# %%
definitivo = merged[['country', 'supermarket', 'restaurant', 'mid-range restaurant', 'mcdonalds', 'wine', 'cigarettes', 'rent', 'utilities', 'internet', 'fitness', 'cinema', 'public transport', 'car', 'salary', 'happiness']]

# %%
definitivo.head()
# Out:
#       country  supermarket  restaurant  mid-range restaurant  mcdonalds  wine  \
# 0  Kazakhstan        22.51        4.75                 23.75       4.28  4.75
# 1    Paraguay        21.52        3.45                 20.72       3.52  5.53
# 2    Portugal        33.51        7.50                 30.00       6.00  4.00
# 3       Syria        20.82        3.61                 14.00       3.61  2.94
# 4      Greece        37.29       10.00                 31.00       6.00  6.25
#
#    cigarettes    rent  utilities  internet  fitness  cinema  public transport  \
# 0        0.95  266.08      49.38     10.40    37.80    3.56             16.63
# 1        1.38  220.26      44.63     25.79    22.27    4.83             21.02
# 2        5.00  619.65      96.61     31.86    32.75    7.00             35.00
# 3        2.34  176.54      17.15     30.94    13.07    4.38              9.68
# 4        4.50  323.04     145.67     30.81    32.34    8.00             30.00
#
# ...
